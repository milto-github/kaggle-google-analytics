# %%
import pandas as pd

df = pd.read_csv('./all/clean_train.csv', dtype={'fullVisitorId': str})

# %% [markdown]
# ---
# ### The 98.7% of rows in transactionRevenue are NaN
# * NaN should imply no revenue.

# %%
nan_revenue_count = df['totals/transactionRevenue'].isnull().values.sum()
print('{0} NaN / {1} Total = {2}'.format(nan_revenue_count, len(df), nan_revenue_count / len(df)))
# Out:
# 892138 NaN / 903653 Total = 0.9872572768529513

# %%
df['totals/transactionRevenue'].fillna(0.00, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

corr_matrix = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, vmin=-1, vmax=1, fmt='.2f')
plt.show()

# %%
df = df.head(10000)
df.columns
# Out:
# Index(['totals/transactionRevenue', 'hour', 'day', 'month', 'year',
#        'trafficSource/source', 'trafficSource/referralPath',
#        'trafficSource/medium', 'trafficSource/isTrueDirect',
#        'trafficSource/adwordsClickInfo/slot',
#        'trafficSource/adwordsClickInfo/page',
#        'trafficSource/adwordsClickInfo/isVideoAd',
#        'trafficSource/adwordsClickInfo/adNetworkType',
#        'trafficSource/adContent', 'totals/pageviews', 'totals/hits',
#        'geoNetwork/subContinent', 'geoNetwork/country', 'geoNetwork/continent',
#        'device/operatingSystem', 'device/isMobile', 'device/deviceCategory',
#        'device/browser', 'visitNumber', 'visitId', 'sessionId',
#        'fullVisitorId', 'channelGrouping'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))

df['geoNetwork/continent'].value_counts().plot.bar()

# %%
df['trafficSource/source'].value_counts().head(10).plot.bar()

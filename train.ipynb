# %%
import pandas as pd

df = pd.read_csv('./all/clean_train.csv', dtype={'fullVisitorId': str})
df.head()
# Out:
#    Unnamed: 0 channelGrouping        fullVisitorId  \
# 0           0  Organic Search  1131660440785968503
# 1           1  Organic Search   377306020877927890
# 2           2  Organic Search  3895546263509774583
# 3           3  Organic Search  4763447161404445595
# 4           4  Organic Search    27294437909732085
#
#                         sessionId     visitId  visitNumber device/browser  \
# 0  1131660440785968503_1472830385  1472830385            1         Chrome
# 1   377306020877927890_1472880147  1472880147            1        Firefox
# 2  3895546263509774583_1472865386  1472865386            1         Chrome
# 3  4763447161404445595_1472881213  1472881213            1     UC Browser
# 4    27294437909732085_1472822600  1472822600            2         Chrome
#
#   device/deviceCategory  device/isMobile device/operatingSystem    ...      \
# 0               desktop            False                Windows    ...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                        int64
# channelGrouping                                  object
# fullVisitorId                                    object
# sessionId                                        object
# visitId                                           int64
# visitNumber                                       int64
# device/browser                                   object
# device/deviceCategory                            object
# device/isMobile                                    bool
# device/operatingSystem                           object
# geoNetwork/continent                             object
# geoNetwork/country                               object
# geoNetwork/subContinent                          object
# totals/bounces                                  float64
# totals/hits                                     float64
# totals/newVisits                                float64
# totals/pageviews                                float64
# ...

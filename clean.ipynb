# %% [markdown]
# # Initial Read/JSON Conversions

# %%
import pandas as pd
from pandas.io.json import loads, json_normalize
    
df = pd.read_csv('./all/train.csv', dtype={'fullVisitorId': str})

# %% [markdown]
# * Function to parse json columns

# %%
# CLEAN STEP 1
def parse_json_cols(df):
    json_cols = ['device', 'geoNetwork', 'totals', 'trafficSource']

    for col in json_cols:
        df_json = json_normalize(df[col].apply(loads), sep='/')
        df_json.columns = [(col + '/' + c) for c in df_json.columns]
        df.drop(columns=col, inplace=True)
        df = pd.concat([df, df_json], axis=1)
    
    return df

# %%
df = parse_json_cols(df)

totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
geoNetwork_cols = list(filter(lambda c : c.startswith('geoNetwork'), df.columns))
device_cols = list(filter(lambda c : c.startswith('device'), df.columns))
trafficSource_cols = list(filter(lambda c : c.startswith('trafficSource'), df.columns))

# %% [markdown]
# # Examine JSON Data

# %% [markdown]
# ### totals/
# * These fields should be treated as numeric values, not objects
# * Cast them to fix this issue

# %%
# CLEAN STEP 2

def cast_totals(df):
    totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
    for i in totals_cols:
        df[i] = df[i].astype(float)
    return df

# %%
df = cast_totals(df)

# %%
df[totals_cols].describe()
# Out:
#        totals/bounces    totals/hits  totals/newVisits  totals/pageviews  \
# count        450630.0  903653.000000          703060.0     903553.000000
# mean              1.0       4.596538               1.0          3.849764
# std               0.0       9.641437               0.0          7.025274
# min               1.0       1.000000               1.0          1.000000
# 25%               1.0       1.000000               1.0          1.000000
# 50%               1.0       2.000000               1.0          1.000000
# 75%               1.0       4.000000               1.0          4.000000
# max               1.0     500.000000               1.0        469.000000
#
#        totals/transactionRevenue  totals/visits
# count               1.151500e+04       903653.0
# mean                1.337448e+08            1.0
# std                 4.482852e+08            0.0
# min                 1.000000e+04            1.0
# 25%                 2.493000e+07            1.0
# 50%                 4.945000e+07            1.0
# 75%                 1.076550e+08            1.0
# max                 2.312950e+10            1.0

# %% [markdown]
# ---
# * The visits, newVisits, and bounces columns only has 1 unique value

# %%
# CLEAN STEP 3
def drop_visits(df):
    df.drop(columns=['totals/visits', 'totals/newVisits', 'totals/bounces'], inplace=True)
    return df

# %%
df = drop_visits(df)

totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
df[totals_cols].describe()
# Out:
#          totals/hits  totals/pageviews  totals/transactionRevenue
# count  903653.000000     903553.000000               1.151500e+04
# mean        4.596538          3.849764               1.337448e+08
# std         9.641437          7.025274               4.482852e+08
# min         1.000000          1.000000               1.000000e+04
# 25%         1.000000          1.000000               2.493000e+07
# 50%         2.000000          1.000000               4.945000e+07
# 75%         4.000000          4.000000               1.076550e+08
# max       500.000000        469.000000               2.312950e+10

# %% [markdown]
# ---
# ### geoNetwork/

# %%
df[geoNetwork_cols].describe()
# Out:
#                       geoNetwork/city              geoNetwork/cityId  \
# count                          903653                         903653
# unique                            649                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           508229                         903653
#
#        geoNetwork/continent geoNetwork/country            geoNetwork/latitude  \
# count                903653             903653                         903653
# unique                    6                222                              1
# top                Americas      United States  not available in demo dataset
# freq                 450377             364744                         903653
#
#                  geoNetwork/longitude               geoNetwork/metro  \
# count                          903653                         903653
# unique                              1                             94
# top     not available in demo dataset  not available in demo dataset
# freq                           903653                         508229
#
#        geoNetwork/networkDomain     geoNetwork/networkLocation  \
# count                    903653                         903653
# unique                    28064                              1
# top                   (not set)  not available in demo dataset
# freq                     244881                         903653
#
#                     geoNetwork/region geoNetwork/subContinent
# count                          903653                  903653
# unique                            376                      23
# top     not available in demo dataset        Northern America
# freq                           508229                  390657

# %% [markdown]
# * most columns have the majority (or all of their values) as "not available in demo dataset" or "(not set)"
#         * city, cityId, latitude, longitude, metro, networkLocation, region, networkDomain
# ---
# **Dropping listed columns:**

# %%
# CLEAN STEP 4
def drop_geo_cols(df):
    df.drop(columns=['geoNetwork/city', 'geoNetwork/cityId', 'geoNetwork/latitude', 'geoNetwork/longitude', 
                 'geoNetwork/metro', 'geoNetwork/networkLocation','geoNetwork/region', 'geoNetwork/networkDomain'], 
                 inplace=True)
    return df

# %%
df = drop_geo_cols(df)

geoNetwork_cols = list(filter(lambda c : c.startswith('geoNetwork'), df.columns))
df[geoNetwork_cols].describe()
# Out:
#        geoNetwork/continent geoNetwork/country geoNetwork/subContinent
# count                903653             903653                  903653
# unique                    6                222                      23
# top                Americas      United States        Northern America
# freq                 450377             364744                  390657

# %% [markdown]
# ---
# ### device/
# * Again, mosts columns only have one value: "not available in demo dataset"
#         * browserSize, browserVersion, flashVersion, language, mobileDeviceBranding, mobileDeviceInfo, mobileDeviceMarketingName, mobileDeviceModel, mobileInputSelector, operatingSystemVersion, screenColors, screenResolution

# %%
df[device_cols].describe()
# Out:
#        device/browser             device/browserSize  \
# count          903653                         903653
# unique             54                              1
# top            Chrome  not available in demo dataset
# freq           620364                         903653
#
#                 device/browserVersion device/deviceCategory  \
# count                          903653                903653
# unique                              1                     3
# top     not available in demo dataset               desktop
# freq                           903653                664479
#
#                   device/flashVersion device/isMobile  \
# count                          903653          903653
# unique                              1               2
# top     not available in demo dataset           False
# freq                           903653          664530
#
#                       device/language    device/mobileDeviceBranding  \
# count                          903653                         903653
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           903653                         903653
#
#               device/mobileDeviceInfo device/mobileDeviceMarketingName  \
# count                          903653                           903653
# unique                              1                                1
# top     not available in demo dataset    not available in demo dataset
# freq                           903653                           903653
#
#              device/mobileDeviceModel     device/mobileInputSelector  \
# count                          903653                         903653
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           903653                         903653
#
#        device/operatingSystem  device/operatingSystemVersion  \
# count                  903653                         903653
# unique                     20                              1
# top                   Windows  not available in demo dataset
# freq                   350072                         903653
#
#                   device/screenColors        device/screenResolution
# count                          903653                         903653
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           903653                         903653

# %% [markdown]
# ---
# **Dropping listed columns:**

# %%
# CLEAN STEP 5
def drop_device_cols(df):
    df.drop(columns=['device/browserSize', 'device/browserVersion', 'device/flashVersion', 'device/language',
                 'device/mobileDeviceBranding', 'device/mobileDeviceInfo', 'device/mobileDeviceMarketingName', 'device/mobileDeviceModel',
                 'device/mobileInputSelector', 'device/operatingSystemVersion', 'device/screenColors', 'device/screenResolution'],
                 inplace=True)
    return df

# %%
df = drop_device_cols(df)

device_cols = list(filter(lambda c : c.startswith('device'), df.columns))
df[device_cols].describe()
# Out:
#        device/browser device/deviceCategory device/isMobile  \
# count          903653                903653          903653
# unique             54                     3               2
# top            Chrome               desktop           False
# freq           620364                664479          664530
#
#        device/operatingSystem
# count                  903653
# unique                     20
# top                   Windows
# freq                   350072

# %% [markdown]
# ---
# ### trafficSource/
# * A few columns here have majority "not available in demo dataset", "(not set)", "(not provided)" values:
#         * adwordsClickInfo/criteriaParameters, campaign, keyword
# * Column "campaignCode" has only one entry. "gclId" has only 70.

# %%
df[trafficSource_cols].describe()
# Out:
#               trafficSource/adContent  \
# count                           10946
# unique                             44
# top     Google Merchandise Collection
# freq                             5122
#
#        trafficSource/adwordsClickInfo/adNetworkType  \
# count                                         21460
# unique                                            2
# top                                   Google Search
# freq                                          21453
#
#        trafficSource/adwordsClickInfo/criteriaParameters  \
# count                                             903653
# unique                                                 1
# top                        not available in demo dataset
# freq                                              903653
#
#                      trafficSource/adwordsClickInfo/gclId  \
# count                                               21561
# unique                                              17774
# top     Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3Zd...
# freq                                                   70
#
#        trafficSource/adwordsClickInfo/isVideoAd  \
# count                                     21460
# unique                                        1
# top                                       False
# freq                                      21460
#
#        trafficSource/adwordsClickInfo/page  \
# count                                21460
# unique                                   8
# top                                      1
# freq                                 21362
#
#        trafficSource/adwordsClickInfo/slot trafficSource/campaign  \
# count                                21460                 903653
# unique                                   2                     10
# top                                    Top              (not set)
# freq                                 20956                 865347
#
#        trafficSource/campaignCode trafficSource/isTrueDirect  \
# count                           1                     274005
# unique                          1                          1
# top                 11251kjhkvahf                       True
# freq                            1                     274005
#
#        trafficSource/keyword trafficSource/medium trafficSource/referralPath  \
# count                 400724               903653                     330941
# unique                  3659                    7                       1475
# top           (not provided)              organic                          /
# freq                  366363               381561                      75523
#
#        trafficSource/source
# count                903653
# unique                  380
# top                  google
# freq                 400788

# %% [markdown]
# ---
# **Dropping listed columns:**

# %%
# CLEAN STEP 6
def drop_trafficSource_cols(df):
    df.drop(columns=['trafficSource/adwordsClickInfo/criteriaParameters', 'trafficSource/campaign', 'trafficSource/keyword',
                     'trafficSource/adwordsClickInfo/gclId'], inplace=True)
    if 'trafficSource/campaignCode' in df.columns:
        df.drop(columns=['trafficSource/campaignCode'], inplace=True)
    return df

# %%
df = drop_trafficSource_cols(df)

trafficSource_cols = list(filter(lambda c : c.startswith('trafficSource'), df.columns))
df[trafficSource_cols].describe()
# Out:
#               trafficSource/adContent  \
# count                           10946
# unique                             44
# top     Google Merchandise Collection
# freq                             5122
#
#        trafficSource/adwordsClickInfo/adNetworkType  \
# count                                         21460
# unique                                            2
# top                                   Google Search
# freq                                          21453
#
#        trafficSource/adwordsClickInfo/isVideoAd  \
# count                                     21460
# unique                                        1
# top                                       False
# freq                                      21460
#
#        trafficSource/adwordsClickInfo/page  \
# count                                21460
# unique                                   8
# top                                      1
# freq                                 21362
#
#        trafficSource/adwordsClickInfo/slot trafficSource/isTrueDirect  \
# count                                21460                     274005
# unique                                   2                          1
# top                                    Top                       True
# freq                                 20956                     274005
#
#        trafficSource/medium trafficSource/referralPath trafficSource/source
# count                903653                     330941               903653
# unique                    7                       1475                  380
# top                 organic                          /               google
# freq                 381561                      75523               400788

# %% [markdown]
# # Examining Remaining Columns (Non JSON)
# * Dates are not parsed
# * visitStartTime is in POSIX time
#     * visitStartTime makes Date redundant (more information encoded)
# * Looking only at qualitative data shows socialEngagementType only has 1 unique value (therefore contributes no information)

# %%
others = [c for c in df.columns if c not in (totals_cols + geoNetwork_cols + device_cols + trafficSource_cols)]
df[others].head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime
# 0            1      1472830385
# 1            1      1472880147
# 2            1      1472865386
# 3            1      1472881213
# 4            2      1472822600

# %%
df[['channelGrouping', 'socialEngagementType']].describe()
# Out:
#        channelGrouping  socialEngagementType
# count           903653                903653
# unique               8                     1
# top     Organic Search  Not Socially Engaged
# freq            381561                903653

# %% [markdown]
# ---
# **Parsing timestamp and dropping date, socialEngagementType:**

# %%
# CLEAN STEP 7

from datetime import datetime

def parse_dates_clean(df):
    df['visitStartTime'] = df['visitStartTime'].apply(lambda time: datetime.fromtimestamp(time))
    df['year']  = df['visitStartTime'].dt.year
    df['month'] = df['visitStartTime'].dt.month
    df['day']   = df['visitStartTime'].dt.day
    df['hour']  = df['visitStartTime'].dt.hour + (df['visitStartTime'].dt.minute/60)
    df.drop(columns=['date', 'visitStartTime', 'socialEngagementType'], inplace=True)

    return df

# %%
df = parse_dates_clean(df)

others = [c for c in df.columns if c not in (totals_cols + geoNetwork_cols + device_cols + trafficSource_cols)]
df[others].head()
# Out:
#   channelGrouping        fullVisitorId                       sessionId  \
# 0  Organic Search  1131660440785968503  1131660440785968503_1472830385
# 1  Organic Search   377306020877927890   377306020877927890_1472880147
# 2  Organic Search  3895546263509774583  3895546263509774583_1472865386
# 3  Organic Search  4763447161404445595  4763447161404445595_1472881213
# 4  Organic Search    27294437909732085    27294437909732085_1472822600
#
#       visitId  visitNumber  year  month  day       hour
# 0  1472830385            1  2016      9    2  11.550000
# 1  1472880147            1  2016      9    3   1.366667
# 2  1472865386            1  2016      9    2  21.266667
# 3  1472881213            1  2016      9    3   1.666667
# 4  1472822600            2  2016      9    2   9.383333

# %% [markdown]
# ---
# ## Clean Pipeline

# %%
def clean(df):
    df = parse_json_cols(df)
    df = cast_totals(df)
    df = drop_visits(df)
    df = drop_geo_cols(df)
    df = drop_device_cols(df)
    df = drop_trafficSource_cols(df)
    df = parse_dates_clean(df)
    
    return df

# %% [markdown]
# ## Do the same for test dataset

# %%
tdf = pd.read_csv('./all/test.csv', dtype={'fullVisitorId': str})
tdf = clean(tdf)
tdf.head()
# Out:
#   channelGrouping        fullVisitorId                       sessionId  \
# 0  Organic Search  6167871330617112363  6167871330617112363_1508151024
# 1  Organic Search  0643697640977915618  0643697640977915618_1508175522
# 2  Organic Search  6059383810968229466  6059383810968229466_1508143220
# 3  Organic Search  2376720078563423631  2376720078563423631_1508193530
# 4  Organic Search  2314544520795440038  2314544520795440038_1508217442
#
#       visitId  visitNumber device/browser device/deviceCategory  \
# 0  1508151024            2         Chrome               desktop
# 1  1508175522            1         Chrome               desktop
# 2  1508143220            1         Chrome               desktop
# 3  1508193530            1         Safari                mobile
# 4  1508217442            1         Safari               desktop
#
#    device/isMobile device/operatingSystem geoNetwork/continent    ...      \
# 0            False              Macintosh                 Asia    ...
# 1            False                Windows               Europe    ...
# 2            False              Macintosh               Europe    ...
# 3             True                    iOS             Americas    ...
# 4            False              Macintosh             Americas    ...
#
#   trafficSource/adwordsClickInfo/page trafficSource/adwordsClickInfo/slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    trafficSource/isTrueDirect  trafficSource/medium  \
# 0                        True               organic
# 1                         NaN               organic
# 2                         NaN               organic
# 3                         NaN               organic
# 4                         NaN               organic
#
#   trafficSource/referralPath trafficSource/source  year month day       hour
# 0                        NaN               google  2017    10  16   6.833333
# 1                        NaN               google  2017    10  16  13.633333
# 2                        NaN               google  2017    10  16   4.666667
# 3                        NaN               google  2017    10  16  18.633333
# 4                        NaN               google  2017    10  17   1.283333
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Save both clean dataframes

# %%
columns = list(df.columns)
columns.remove('totals/transactionRevenue')
columns.append('totals/transactionRevenue')
df = df[columns[::-1]]
df.to_csv('./all/clean_train.csv')

df.to_csv('./all/clean_train.csv', index=False)
tdf.to_csv('./all/clean_tdf.csv', index=False)

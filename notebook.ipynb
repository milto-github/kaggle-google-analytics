# %% [markdown]
# # Initial Read/JSON Conversions

# %%
import pandas as pd
from pandas.io.json import loads, json_normalize
    
df = pd.read_csv('./all/train.csv', nrows=100000, dtype={'fullVisitorId': str})

# %% [markdown]
# * Function to parse json columns

# %%
# PREPROCESS STEP 1
def parse_json_cols(df):
    json_cols = ['device', 'geoNetwork', 'totals', 'trafficSource']

    for col in json_cols:
        df_json = json_normalize(df[col].apply(loads), sep='/')
        df_json.columns = [(col + '/' + c) for c in df_json.columns]
        df.drop(columns=col, inplace=True)
        df = pd.concat([df, df_json], axis=1)
    
    return df

# %%
df = parse_json_cols(df)

totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
geoNetwork_cols = list(filter(lambda c : c.startswith('geoNetwork'), df.columns))
device_cols = list(filter(lambda c : c.startswith('device'), df.columns))
trafficSource_cols = list(filter(lambda c : c.startswith('trafficSource'), df.columns))

# %% [markdown]
# # Examine JSON Data

# %% [markdown]
# ### totals/
# * These fields should be treated as numeric values, not objects
# * Cast them to fix this issue

# %%
# PREPROCESS STEP 2

def cast_totals(df):
    totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
    for i in totals_cols:
        df[i] = df[i].astype(float)
    return df

# %%
df = cast_totals(df)

# %%
df[totals_cols].describe()
# Out:
#        totals/bounces    totals/hits  totals/newVisits  totals/pageviews  \
# count         48916.0  100000.000000           77263.0      99993.000000
# mean              1.0       4.622350               1.0          3.868151
# std               0.0       9.620067               0.0          6.981922
# min               1.0       1.000000               1.0          1.000000
# 25%               1.0       1.000000               1.0          1.000000
# 50%               1.0       2.000000               1.0          2.000000
# 75%               1.0       4.000000               1.0          4.000000
# max               1.0     500.000000               1.0        400.000000
#
#        totals/transactionRevenue  totals/visits
# count               1.399000e+03       100000.0
# mean                1.300507e+08            1.0
# std                 3.036366e+08            0.0
# min                 1.200000e+06            1.0
# 25%                 2.499000e+07            1.0
# 50%                 5.000000e+07            1.0
# 75%                 1.096250e+08            1.0
# max                 5.498000e+09            1.0

# %% [markdown]
# ---
# * The visits column only has 1 unique value

# %%
# Preprocess step 3
def drop_visits(df):
    df.drop(columns=['totals/visits'], inplace=True)
    return df

# %%
df = drop_visits(df)

totals_cols = list(filter(lambda c : c.startswith('totals'), df.columns))
df[totals_cols].describe()
# Out:
#        totals/bounces    totals/hits  totals/newVisits  totals/pageviews  \
# count         48916.0  100000.000000           77263.0      99993.000000
# mean              1.0       4.622350               1.0          3.868151
# std               0.0       9.620067               0.0          6.981922
# min               1.0       1.000000               1.0          1.000000
# 25%               1.0       1.000000               1.0          1.000000
# 50%               1.0       2.000000               1.0          2.000000
# 75%               1.0       4.000000               1.0          4.000000
# max               1.0     500.000000               1.0        400.000000
#
#        totals/transactionRevenue
# count               1.399000e+03
# mean                1.300507e+08
# std                 3.036366e+08
# min                 1.200000e+06
# 25%                 2.499000e+07
# 50%                 5.000000e+07
# 75%                 1.096250e+08
# max                 5.498000e+09

# %% [markdown]
# ---
# ### geoNetwork/

# %%
df[geoNetwork_cols].describe()
# Out:
#                       geoNetwork/city              geoNetwork/cityId  \
# count                          100000                         100000
# unique                            290                              1
# top     not available in demo dataset  not available in demo dataset
# freq                            55211                         100000
#
#        geoNetwork/continent geoNetwork/country            geoNetwork/latitude  \
# count                100000             100000                         100000
# unique                    6                183                              1
# top                Americas      United States  not available in demo dataset
# freq                  50435              40939                         100000
#
#                  geoNetwork/longitude               geoNetwork/metro  \
# count                          100000                         100000
# unique                              1                             53
# top     not available in demo dataset  not available in demo dataset
# freq                           100000                          55211
#
#        geoNetwork/networkDomain     geoNetwork/networkLocation  \
# count                    100000                         100000
# unique                     7228                              1
# top                   (not set)  not available in demo dataset
# freq                      27820                         100000
#
#                     geoNetwork/region geoNetwork/subContinent
# count                          100000                  100000
# unique                            218                      23
# top     not available in demo dataset        Northern America
# freq                            55211                   43874

# %% [markdown]
# * most columns have the majority (or all of their values) as "not available in demo dataset" or "(not set)"
#         * city, cityId, latitude, longitude, metro, networkLocation, region, networkDomain
# ---
# **Dropping listed columns:**

# %%
# Preprocess step 4
def drop_geo_cols(df):
    df.drop(columns=['geoNetwork/city', 'geoNetwork/cityId', 'geoNetwork/latitude', 'geoNetwork/longitude', 
                 'geoNetwork/metro', 'geoNetwork/networkLocation','geoNetwork/region', 'geoNetwork/networkDomain'], 
                 inplace=True)
    return df

# %%
df = drop_geo_cols(df)

geoNetwork_cols = list(filter(lambda c : c.startswith('geoNetwork'), df.columns))
df[geoNetwork_cols].describe()
# Out:
#        geoNetwork/continent geoNetwork/country geoNetwork/subContinent
# count                100000             100000                  100000
# unique                    6                183                      23
# top                Americas      United States        Northern America
# freq                  50435              40939                   43874

# %% [markdown]
# ---
# ### device/
# * Again, mosts columns only have one value: "not available in demo dataset"
#         * browserSize, browserVersion, flashVersion, language, mobileDeviceBranding, mobileDeviceInfo, mobileDeviceMarketingName, mobileDeviceModel, mobileInputSelector, operatingSystemVersion, screenColors, screenResolution

# %%
df[device_cols].describe()
# Out:
#        device/browser             device/browserSize  \
# count          100000                         100000
# unique             29                              1
# top            Chrome  not available in demo dataset
# freq            68984                         100000
#
#                 device/browserVersion device/deviceCategory  \
# count                          100000                100000
# unique                              1                     3
# top     not available in demo dataset               desktop
# freq                           100000                 74135
#
#                   device/flashVersion device/isMobile  \
# count                          100000          100000
# unique                              1               2
# top     not available in demo dataset           False
# freq                           100000           74141
#
#                       device/language    device/mobileDeviceBranding  \
# count                          100000                         100000
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           100000                         100000
#
#               device/mobileDeviceInfo device/mobileDeviceMarketingName  \
# count                          100000                           100000
# unique                              1                                1
# top     not available in demo dataset    not available in demo dataset
# freq                           100000                           100000
#
#              device/mobileDeviceModel     device/mobileInputSelector  \
# count                          100000                         100000
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           100000                         100000
#
#        device/operatingSystem  device/operatingSystemVersion  \
# count                  100000                         100000
# unique                     16                              1
# top                   Windows  not available in demo dataset
# freq                    38001                         100000
#
#                   device/screenColors        device/screenResolution
# count                          100000                         100000
# unique                              1                              1
# top     not available in demo dataset  not available in demo dataset
# freq                           100000                         100000

# %% [markdown]
# ---
# **Dropping listed columns:**

# %%
# Preprocess step 5
def drop_device_cols(df):
    df.drop(columns=['device/browserSize', 'device/browserVersion', 'device/flashVersion', 'device/language',
                 'device/mobileDeviceBranding', 'device/mobileDeviceInfo', 'device/mobileDeviceMarketingName', 'device/mobileDeviceModel',
                 'device/mobileInputSelector', 'device/operatingSystemVersion', 'device/screenColors', 'device/screenResolution'],
                 inplace=True)
    return df

# %%
df = drop_device_cols(df)

device_cols = list(filter(lambda c : c.startswith('device'), df.columns))
df[device_cols].describe()
# Out:
#        device/browser device/deviceCategory device/isMobile  \
# count          100000                100000          100000
# unique             29                     3               2
# top            Chrome               desktop           False
# freq            68984                 74135           74141
#
#        device/operatingSystem
# count                  100000
# unique                     16
# top                   Windows
# freq                    38001

# %% [markdown]
# ---
# ### trafficSource/
# * A few columns here have majority "not available in demo dataset", "(not set)", "(not provided)" values:
#         * adwordsClickInfo/criteriaParameters, campaign, keyword
# * Column "campaignCode" has only one entry. "gclId" has only 70.

# %%
df[trafficSource_cols].describe()
# Out:
#               trafficSource/adContent  \
# count                            1325
# unique                             31
# top     Google Merchandise Collection
# freq                              662
#
#        trafficSource/adwordsClickInfo/adNetworkType  \
# count                                          2574
# unique                                            2
# top                                   Google Search
# freq                                           2573
#
#        trafficSource/adwordsClickInfo/criteriaParameters  \
# count                                             100000
# unique                                                 1
# top                        not available in demo dataset
# freq                                              100000
#
#                      trafficSource/adwordsClickInfo/gclId  \
# count                                                2625
# unique                                               2389
# top     Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3Zd...
# freq                                                   10
#
#        trafficSource/adwordsClickInfo/isVideoAd  \
# count                                      2574
# unique                                        1
# top                                       False
# freq                                       2574
#
#        trafficSource/adwordsClickInfo/page  \
# count                                 2574
# unique                                   4
# top                                      1
# freq                                  2566
#
#        trafficSource/adwordsClickInfo/slot trafficSource/campaign  \
# count                                 2574                 100000
# unique                                   2                      8
# top                                    Top              (not set)
# freq                                  2527                  95442
#
#        trafficSource/campaignCode trafficSource/isTrueDirect  \
# count                           1                      30454
# unique                          1                          1
# top                 11251kjhkvahf                       True
# freq                            1                      30454
#
#        trafficSource/keyword trafficSource/medium trafficSource/referralPath  \
# count                  44218               100000                      36473
# unique                   643                    7                        527
# top           (not provided)              organic                          /
# freq                   40273                42019                       8731
#
#        trafficSource/source
# count                100000
# unique                  161
# top                  google
# freq                  44448

# %% [markdown]
# ---
# **Dropping listed columns:**

# %%
# Preprocess step 6
def drop_trafficSource_cols(df):
    df.drop(columns=['trafficSource/adwordsClickInfo/criteriaParameters', 'trafficSource/campaign', 'trafficSource/keyword',
                 'trafficSource/campaignCode', 'trafficSource/adwordsClickInfo/gclId'], inplace=True)
    return df

# %%
df = drop_trafficSource_cols(df)

trafficSource_cols = list(filter(lambda c : c.startswith('trafficSource'), df.columns))
df[trafficSource_cols].describe()
# Out:
#               trafficSource/adContent  \
# count                            1325
# unique                             31
# top     Google Merchandise Collection
# freq                              662
#
#        trafficSource/adwordsClickInfo/adNetworkType  \
# count                                          2574
# unique                                            2
# top                                   Google Search
# freq                                           2573
#
#        trafficSource/adwordsClickInfo/isVideoAd  \
# count                                      2574
# unique                                        1
# top                                       False
# freq                                       2574
#
#        trafficSource/adwordsClickInfo/page  \
# count                                 2574
# unique                                   4
# top                                      1
# freq                                  2566
#
#        trafficSource/adwordsClickInfo/slot trafficSource/isTrueDirect  \
# count                                 2574                      30454
# unique                                   2                          1
# top                                    Top                       True
# freq                                  2527                      30454
#
#        trafficSource/medium trafficSource/referralPath trafficSource/source
# count                100000                      36473               100000
# unique                    7                        527                  161
# top                 organic                          /               google
# freq                  42019                       8731                44448

# %% [markdown]
# # Examining Remaining Columns (Non JSON)
# * Dates are not parsed
# * visitStartTime is in POSIX time
# * Looking only at qualitative data shows socialEngagementType only has 1 unique value (therefore contributes no information)

# %%
others = [c for c in df.columns if c not in (totals_cols + geoNetwork_cols + device_cols + trafficSource_cols)]
df[others].head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime
# 0            1      1472830385
# 1            1      1472880147
# 2            1      1472865386
# 3            1      1472881213
# 4            2      1472822600

# %%
df[['channelGrouping', 'socialEngagementType']].describe()
# Out:
#        channelGrouping  socialEngagementType
# count           100000                100000
# unique               8                     1
# top     Organic Search  Not Socially Engaged
# freq             42019                100000

# %%
from datetime import datetime

df['date'] = df['date'].apply(lambda date: datetime.strptime(date, '%Y%m%d'))
df['date'] = df['date'].apply(lambda date: datetime.strptime(date, '%Y%m%d'))

df['visitStartTime'] = pd.to_datetime(train_data["visitStartTime"],unit='s')

df.drop(columns='socialEngagementType', inplace=True)


others = [c for c in df.columns if c not in (totals_cols + geoNetwork_cols + device_cols + trafficSource_cols)]
df[others].head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId     visitId  visitNumber  visitStartTime
# 0  1131660440785968503_1472830385  1472830385            1      1472830385
# 1   377306020877927890_1472880147  1472880147            1      1472880147
# 2  3895546263509774583_1472865386  1472865386            1      1472865386
# 3  4763447161404445595_1472881213  1472881213            1      1472881213
# 4    27294437909732085_1472822600  1472822600            2      1472822600

# %% [markdown]
# ---
# # Back to the full dataset

# %%
tdf = pd.read_csv('./all/test.csv', nrows=100000, dtype={'fullVisitorId': str})
# Out:
#       channelGrouping      date  \
# 0      Organic Search  20171016
# 1      Organic Search  20171016
# 2      Organic Search  20171016
# 3      Organic Search  20171016
# 4      Organic Search  20171016
# 5      Organic Search  20171016
# 6      Organic Search  20171016
# 7      Organic Search  20171016
# 8      Organic Search  20171016
# 9      Organic Search  20171016
# 10     Organic Search  20171016
# 11        Paid Search  20171016
# 12            Display  20171016
# 13     Organic Search  20171016
# 14     Organic Search  20171016
# 15     Organic Search  20171016
# 16     Organic Search  20171016
# 17     Organic Search  20171016
# 18     Organic Search  20171016
# 19     Organic Search  20171016
# 20     Organic Search  20171016
# 21     Organic Search  20171016
# 22     Organic Search  20171016
# 23     Organic Search  20171016
# 24     Organic Search  20171016
# 25             Direct  20171016
# 26        Paid Search  20171016
# 27            Display  20171016
# 28     Organic Search  20171016
# 29        Paid Search  20171016
# ...               ...       ...
# 99970          Direct  20171212
# 99971          Direct  20171212
# 99972          Direct  20171212
# 99973          Direct  20171212
# 99974          Direct  20171212
# 99975          Direct  20171212
# 99976          Direct  20171212
# 99977          Direct  20171212
# 99978          Direct  20171212
# 99979          Direct  20171212
# 99980          Direct  20171212
# 99981          Direct  20171212
# 99982          Direct  20171212
# 99983          Direct  20171212
# 99984          Direct  20171212
# 99985          Direct  20171212
# 99986          Direct  20171212
# 99987          Direct  20171212
# 99988          Direct  20171212
# 99989          Direct  20171212
# 99990          Direct  20171212
# 99991          Direct  20171212
# 99992          Direct  20171212
# 99993          Direct  20171212
# 99994          Direct  20171212
# 99995          Direct  20171212
# 99996          Direct  20171212
# 99997  Organic Search  20171212
# 99998  Organic Search  20171212
# 99999        Referral  20171212
#
#                                                   device        fullVisitorId  \
# 0      {"browser": "Chrome", "browserVersion": "not a...  6167871330617112363
# 1      {"browser": "Chrome", "browserVersion": "not a...  0643697640977915618
# 2      {"browser": "Chrome", "browserVersion": "not a...  6059383810968229466
# 3      {"browser": "Safari", "browserVersion": "not a...  2376720078563423631
# 4      {"browser": "Safari", "browserVersion": "not a...  2314544520795440038
# 5      {"browser": "Chrome", "browserVersion": "not a...  4133039884103392367
# 6      {"browser": "Chrome", "browserVersion": "not a...  4320478850207397557
# 7      {"browser": "Chrome", "browserVersion": "not a...  5876438247590157131
# 8      {"browser": "Chrome", "browserVersion": "not a...  0514591268737702944
# 9      {"browser": "Chrome", "browserVersion": "not a...  6430567031531677212
# 10     {"browser": "Chrome", "browserVersion": "not a...  7026374070157240653
# 11     {"browser": "Chrome", "browserVersion": "not a...  2861724304134353779
# 12     {"browser": "Chrome", "browserVersion": "not a...  7908247117289630366
# 13     {"browser": "Chrome", "browserVersion": "not a...  4452127952351664046
# 14     {"browser": "Chrome", "browserVersion": "not a...  5164677450498536535
# 15     {"browser": "Safari", "browserVersion": "not a...  1172736694169070530
# 16     {"browser": "Chrome", "browserVersion": "not a...  2227276092641173528
# 17     {"browser": "Chrome", "browserVersion": "not a...  6097905367189223328
# 18     {"browser": "Chrome", "browserVersion": "not a...  2875748411381301550
# 19     {"browser": "Chrome", "browserVersion": "not a...   106322241208490482
# 20     {"browser": "Chrome", "browserVersion": "not a...  2539146239106597280
# 21     {"browser": "Safari", "browserVersion": "not a...  8292302978090732261
# 22     {"browser": "Chrome", "browserVersion": "not a...  3568087592858727246
# 23     {"browser": "Chrome", "browserVersion": "not a...  0131485980404703767
# 24     {"browser": "Safari", "browserVersion": "not a...  0953429090981710815
# 25     {"browser": "Chrome", "browserVersion": "not a...  6607438459060540448
# 26     {"browser": "Chrome", "browserVersion": "not a...  0714644457055331984
# 27     {"browser": "Chrome", "browserVersion": "not a...   387955796648318420
# 28     {"browser": "Chrome", "browserVersion": "not a...  8375379770594309032
# 29     {"browser": "Safari", "browserVersion": "not a...  5881635424865422087
# ...                                                  ...                  ...
# 99970  {"browser": "Chrome", "browserVersion": "not a...  7830176069883591179
# 99971  {"browser": "Chrome", "browserVersion": "not a...  7942619844031167953
# 99972  {"browser": "Safari", "browserVersion": "not a...  8577852528800927287
# 99973  {"browser": "Chrome", "browserVersion": "not a...  6371293951037356286
# 99974  {"browser": "Samsung Internet", "browserVersio...   481224774068629464
# 99975  {"browser": "Samsung Internet", "browserVersio...  9396950505446385655
# 99976  {"browser": "Chrome", "browserVersion": "not a...  1999200179943856618
# 99977  {"browser": "Chrome", "browserVersion": "not a...  3783133443705668526
# 99978  {"browser": "Chrome", "browserVersion": "not a...  8264785773642427488
# 99979  {"browser": "Chrome", "browserVersion": "not a...  6473112497103167270
# 99980  {"browser": "Chrome", "browserVersion": "not a...  1552350367533488394
# 99981  {"browser": "Chrome", "browserVersion": "not a...  9987466030174217986
# 99982  {"browser": "Chrome", "browserVersion": "not a...  6006089134423134803
# 99983  {"browser": "Safari", "browserVersion": "not a...  4203943550150245611
# 99984  {"browser": "Safari", "browserVersion": "not a...   156879911420575973
# 99985  {"browser": "Safari", "browserVersion": "not a...  4681773910570455172
# 99986  {"browser": "YaBrowser", "browserVersion": "no...  8445228478281752894
# 99987  {"browser": "Chrome", "browserVersion": "not a...   536056577730069310
# 99988  {"browser": "Samsung Internet", "browserVersio...  3429468177220212993
# 99989  {"browser": "Safari", "browserVersion": "not a...  9081728569702980324
# 99990  {"browser": "Chrome", "browserVersion": "not a...  8268323803819609454
# 99991  {"browser": "Chrome", "browserVersion": "not a...  6404090389138950208
# 99992  {"browser": "Chrome", "browserVersion": "not a...  8608066456648486581
# 99993  {"browser": "Chrome", "browserVersion": "not a...  9641401134057433741
# 99994  {"browser": "Android Browser", "browserVersion...  5832526858047244026
# 99995  {"browser": "Chrome", "browserVersion": "not a...  9221909455174943891
# 99996  {"browser": "Chrome", "browserVersion": "not a...  4692700674854808847
# 99997  {"browser": "Chrome", "browserVersion": "not a...  4186432483649184842
# 99998  {"browser": "Chrome", "browserVersion": "not a...  1072728381569111338
# 99999  {"browser": "Chrome", "browserVersion": "not a...  4718003911953328868
#
#                                               geoNetwork  \
# 0      {"continent": "Asia", "subContinent": "Southea...
# 1      {"continent": "Europe", "subContinent": "South...
# 2      {"continent": "Europe", "subContinent": "Weste...
# 3      {"continent": "Americas", "subContinent": "Nor...
# 4      {"continent": "Americas", "subContinent": "Nor...
# 5      {"continent": "Americas", "subContinent": "Nor...
# 6      {"continent": "Americas", "subContinent": "Nor...
# 7      {"continent": "Americas", "subContinent": "Nor...
# 8      {"continent": "Europe", "subContinent": "South...
# 9      {"continent": "Europe", "subContinent": "South...
# 10     {"continent": "Americas", "subContinent": "Nor...
# 11     {"continent": "Americas", "subContinent": "Nor...
# 12     {"continent": "Americas", "subContinent": "Nor...
# 13     {"continent": "Americas", "subContinent": "Nor...
# 14     {"continent": "Americas", "subContinent": "Nor...
# 15     {"continent": "Europe", "subContinent": "Weste...
# 16     {"continent": "Europe", "subContinent": "Weste...
# 17     {"continent": "Americas", "subContinent": "Nor...
# 18     {"continent": "Americas", "subContinent": "Nor...
# 19     {"continent": "Americas", "subContinent": "Cen...
# 20     {"continent": "Americas", "subContinent": "Nor...
# 21     {"continent": "Europe", "subContinent": "Weste...
# 22     {"continent": "Americas", "subContinent": "Nor...
# 23     {"continent": "Americas", "subContinent": "Nor...
# 24     {"continent": "Americas", "subContinent": "Nor...
# 25     {"continent": "Americas", "subContinent": "Nor...
# 26     {"continent": "Americas", "subContinent": "Nor...
# 27     {"continent": "Americas", "subContinent": "Nor...
# 28     {"continent": "Americas", "subContinent": "Nor...
# 29     {"continent": "Americas", "subContinent": "Nor...
# ...                                                  ...
# 99970  {"continent": "Americas", "subContinent": "Nor...
# 99971  {"continent": "Americas", "subContinent": "Nor...
# 99972  {"continent": "Americas", "subContinent": "Nor...
# 99973  {"continent": "Americas", "subContinent": "Cen...
# 99974  {"continent": "Americas", "subContinent": "Nor...
# 99975  {"continent": "Americas", "subContinent": "Cen...
# 99976  {"continent": "Americas", "subContinent": "Sou...
# 99977  {"continent": "Americas", "subContinent": "Nor...
# 99978  {"continent": "Americas", "subContinent": "Nor...
# 99979  {"continent": "Americas", "subContinent": "Cen...
# 99980  {"continent": "Americas", "subContinent": "Sou...
# 99981  {"continent": "Americas", "subContinent": "Sou...
# 99982  {"continent": "Americas", "subContinent": "Nor...
# 99983  {"continent": "Americas", "subContinent": "Nor...
# 99984  {"continent": "Americas", "subContinent": "Nor...
# 99985  {"continent": "Americas", "subContinent": "Car...
# 99986  {"continent": "Europe", "subContinent": "Easte...
# 99987  {"continent": "Americas", "subContinent": "Cen...
# 99988  {"continent": "Europe", "subContinent": "South...
# 99989  {"continent": "Americas", "subContinent": "Nor...
# 99990  {"continent": "Americas", "subContinent": "Car...
# 99991  {"continent": "Americas", "subContinent": "Nor...
# 99992  {"continent": "Americas", "subContinent": "Nor...
# 99993  {"continent": "Americas", "subContinent": "Nor...
# 99994  {"continent": "Americas", "subContinent": "Cen...
# 99995  {"continent": "Americas", "subContinent": "Nor...
# 99996  {"continent": "Americas", "subContinent": "Nor...
# 99997  {"continent": "Americas", "subContinent": "Nor...
# 99998  {"continent": "Americas", "subContinent": "Nor...
# 99999  {"continent": "Americas", "subContinent": "Nor...
#
#                             sessionId  socialEngagementType  \
# 0      6167871330617112363_1508151024  Not Socially Engaged
# 1      0643697640977915618_1508175522  Not Socially Engaged
# 2      6059383810968229466_1508143220  Not Socially Engaged
# 3      2376720078563423631_1508193530  Not Socially Engaged
# 4      2314544520795440038_1508217442  Not Socially Engaged
# 5      4133039884103392367_1508186358  Not Socially Engaged
# 6      4320478850207397557_1508203650  Not Socially Engaged
# 7      5876438247590157131_1508184397  Not Socially Engaged
# 8      0514591268737702944_1508189652  Not Socially Engaged
# 9      6430567031531677212_1508175502  Not Socially Engaged
# 10     7026374070157240653_1508190324  Not Socially Engaged
# 11     2861724304134353779_1508196731  Not Socially Engaged
# 12     7908247117289630366_1508186327  Not Socially Engaged
# 13     4452127952351664046_1508184708  Not Socially Engaged
# 14     5164677450498536535_1508186650  Not Socially Engaged
# 15     1172736694169070530_1508142222  Not Socially Engaged
# 16     2227276092641173528_1508170696  Not Socially Engaged
# 17     6097905367189223328_1508218860  Not Socially Engaged
# 18     2875748411381301550_1508187456  Not Socially Engaged
# 19      106322241208490482_1508191999  Not Socially Engaged
# 20     2539146239106597280_1508207776  Not Socially Engaged
# 21     8292302978090732261_1508166599  Not Socially Engaged
# 22     3568087592858727246_1508153480  Not Socially Engaged
# 23     0131485980404703767_1508201784  Not Socially Engaged
# 24     0953429090981710815_1508193746  Not Socially Engaged
# 25     6607438459060540448_1508179515  Not Socially Engaged
# 26     0714644457055331984_1508185294  Not Socially Engaged
# 27      387955796648318420_1508195772  Not Socially Engaged
# 28     8375379770594309032_1508213189  Not Socially Engaged
# 29     5881635424865422087_1508208683  Not Socially Engaged
# ...                               ...                   ...
# 99970  7830176069883591179_1513125912  Not Socially Engaged
# 99971  7942619844031167953_1513125898  Not Socially Engaged
# 99972  8577852528800927287_1513124944  Not Socially Engaged
# 99973  6371293951037356286_1513132402  Not Socially Engaged
# 99974   481224774068629464_1513143094  Not Socially Engaged
# 99975  9396950505446385655_1513124915  Not Socially Engaged
# 99976  1999200179943856618_1513125210  Not Socially Engaged
# 99977  3783133443705668526_1513125109  Not Socially Engaged
# 99978  8264785773642427488_1513125627  Not Socially Engaged
# 99979  6473112497103167270_1513125076  Not Socially Engaged
# 99980  1552350367533488394_1513125415  Not Socially Engaged
# 99981  9987466030174217986_1513125378  Not Socially Engaged
# 99982  6006089134423134803_1513124983  Not Socially Engaged
# 99983  4203943550150245611_1513126925  Not Socially Engaged
# 99984   156879911420575973_1513125082  Not Socially Engaged
# 99985  4681773910570455172_1513125122  Not Socially Engaged
# 99986  8445228478281752894_1513126662  Not Socially Engaged
# 99987   536056577730069310_1513125201  Not Socially Engaged
# 99988  3429468177220212993_1513128278  Not Socially Engaged
# 99989  9081728569702980324_1513125037  Not Socially Engaged
# 99990  8268323803819609454_1513139781  Not Socially Engaged
# 99991  6404090389138950208_1513125068  Not Socially Engaged
# 99992  8608066456648486581_1513125051  Not Socially Engaged
# 99993  9641401134057433741_1513125101  Not Socially Engaged
# 99994  5832526858047244026_1513143644  Not Socially Engaged
# 99995  9221909455174943891_1513126207  Not Socially Engaged
# 99996  4692700674854808847_1513124975  Not Socially Engaged
# 99997  4186432483649184842_1513104037  Not Socially Engaged
# 99998  1072728381569111338_1513118243  Not Socially Engaged
# 99999  4718003911953328868_1513124906  Not Socially Engaged
#
#                                                   totals  \
# 0         {"visits": "1", "hits": "4", "pageviews": "4"}
# 1      {"visits": "1", "hits": "5", "pageviews": "5",...
# 2      {"visits": "1", "hits": "7", "pageviews": "7",...
# 3      {"visits": "1", "hits": "8", "pageviews": "4",...
# 4      {"visits": "1", "hits": "9", "pageviews": "4",...
# 5      {"visits": "1", "hits": "11", "pageviews": "5"...
# 6      {"visits": "1", "hits": "37", "pageviews": "15...
# 7      {"visits": "1", "hits": "52", "pageviews": "22...
# 8         {"visits": "1", "hits": "5", "pageviews": "5"}
# 9      {"visits": "1", "hits": "6", "pageviews": "6",...
# 10     {"visits": "1", "hits": "10", "pageviews": "10...
# 11     {"visits": "1", "hits": "3", "pageviews": "3",...
# 12     {"visits": "1", "hits": "3", "pageviews": "3",...
# 13     {"visits": "1", "hits": "3", "pageviews": "3",...
# 14     {"visits": "1", "hits": "3", "pageviews": "3",...
# 15     {"visits": "1", "hits": "3", "pageviews": "3",...
# 16     {"visits": "1", "hits": "3", "pageviews": "3",...
# 17     {"visits": "1", "hits": "3", "pageviews": "3",...
# 18     {"visits": "1", "hits": "3", "pageviews": "3",...
# 19     {"visits": "1", "hits": "3", "pageviews": "3",...
# 20     {"visits": "1", "hits": "3", "pageviews": "3",...
# 21        {"visits": "1", "hits": "3", "pageviews": "3"}
# 22     {"visits": "1", "hits": "3", "pageviews": "3",...
# 23        {"visits": "1", "hits": "3", "pageviews": "3"}
# 24     {"visits": "1", "hits": "3", "pageviews": "3",...
# 25     {"visits": "1", "hits": "3", "pageviews": "3",...
# 26        {"visits": "1", "hits": "3", "pageviews": "3"}
# 27     {"visits": "1", "hits": "4", "pageviews": "4",...
# 28     {"visits": "1", "hits": "4", "pageviews": "4",...
# 29        {"visits": "1", "hits": "4", "pageviews": "4"}
# ...                                                  ...
# 99970  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99971  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99972  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99973  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99974  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99975  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99976  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99977  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99978  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99979  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99980  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99981  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99982  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99983  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99984  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99985  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99986  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99987  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99988  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99989  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99990  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99991  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99992  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99993  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99994  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99995  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99996  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99997  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99998  {"visits": "1", "hits": "1", "pageviews": "1",...
# 99999  {"visits": "1", "hits": "1", "pageviews": "1",...
#
#                                            trafficSource     visitId  \
# 0      {"campaign": "(not set)", "source": "google", ...  1508151024
# 1      {"campaign": "(not set)", "source": "google", ...  1508175522
# 2      {"campaign": "(not set)", "source": "google", ...  1508143220
# 3      {"campaign": "(not set)", "source": "google", ...  1508193530
# 4      {"campaign": "(not set)", "source": "google", ...  1508217442
# 5      {"campaign": "(not set)", "source": "google", ...  1508186358
# 6      {"campaign": "(not set)", "source": "google", ...  1508203650
# 7      {"campaign": "(not set)", "source": "google", ...  1508184397
# 8      {"campaign": "(not set)", "source": "google", ...  1508189652
# 9      {"campaign": "(not set)", "source": "google", ...  1508175502
# 10     {"campaign": "(not set)", "source": "google", ...  1508190324
# 11     {"campaign": "AW - Dynamic Search Ads Whole Si...  1508196731
# 12     {"campaign": "(not set)", "source": "google", ...  1508186327
# 13     {"campaign": "(not set)", "source": "google", ...  1508184708
# 14     {"campaign": "(not set)", "source": "google", ...  1508186650
# 15     {"campaign": "(not set)", "source": "google", ...  1508142222
# 16     {"campaign": "(not set)", "source": "google", ...  1508170696
# 17     {"campaign": "(not set)", "source": "google", ...  1508218860
# 18     {"campaign": "(not set)", "source": "google", ...  1508187456
# 19     {"campaign": "(not set)", "source": "google", ...  1508191999
# 20     {"campaign": "(not set)", "source": "google", ...  1508207776
# 21     {"campaign": "(not set)", "source": "google", ...  1508166599
# 22     {"campaign": "(not set)", "source": "google", ...  1508153480
# 23     {"campaign": "(not set)", "source": "google", ...  1508201784
# 24     {"campaign": "(not set)", "source": "google", ...  1508193746
# 25     {"campaign": "(not set)", "source": "(direct)"...  1508179515
# 26     {"campaign": "AW - Dynamic Search Ads Whole Si...  1508185294
# 27     {"campaign": "(not set)", "source": "google", ...  1508195772
# 28     {"campaign": "(not set)", "source": "google", ...  1508213189
# 29     {"campaign": "AW - Dynamic Search Ads Whole Si...  1508208683
# ...                                                  ...         ...
# 99970  {"campaign": "(not set)", "source": "(direct)"...  1513125912
# 99971  {"campaign": "(not set)", "source": "(direct)"...  1513125898
# 99972  {"campaign": "(not set)", "source": "(direct)"...  1513124944
# 99973  {"campaign": "(not set)", "source": "(direct)"...  1513132402
# 99974  {"campaign": "(not set)", "source": "(direct)"...  1513143094
# 99975  {"campaign": "(not set)", "source": "(direct)"...  1513124915
# 99976  {"campaign": "(not set)", "source": "(direct)"...  1513125210
# 99977  {"campaign": "(not set)", "source": "(direct)"...  1513125109
# 99978  {"campaign": "(not set)", "source": "(direct)"...  1513125627
# 99979  {"campaign": "(not set)", "source": "(direct)"...  1513125076
# 99980  {"campaign": "(not set)", "source": "(direct)"...  1513125415
# 99981  {"campaign": "(not set)", "source": "(direct)"...  1513125378
# 99982  {"campaign": "(not set)", "source": "(direct)"...  1513124983
# 99983  {"campaign": "(not set)", "source": "(direct)"...  1513126925
# 99984  {"campaign": "(not set)", "source": "(direct)"...  1513125082
# 99985  {"campaign": "(not set)", "source": "(direct)"...  1513125122
# 99986  {"campaign": "(not set)", "source": "(direct)"...  1513126662
# 99987  {"campaign": "(not set)", "source": "(direct)"...  1513125201
# 99988  {"campaign": "(not set)", "source": "(direct)"...  1513128278
# 99989  {"campaign": "(not set)", "source": "(direct)"...  1513125037
# 99990  {"campaign": "(not set)", "source": "(direct)"...  1513139781
# 99991  {"campaign": "(not set)", "source": "(direct)"...  1513125068
# 99992  {"campaign": "(not set)", "source": "(direct)"...  1513125051
# 99993  {"campaign": "(not set)", "source": "(direct)"...  1513125101
# 99994  {"campaign": "(not set)", "source": "(direct)"...  1513143644
# 99995  {"campaign": "(not set)", "source": "(direct)"...  1513126207
# 99996  {"campaign": "(not set)", "source": "(direct)"...  1513124975
# 99997  {"campaign": "(not set)", "source": "google", ...  1513104037
# 99998  {"campaign": "(not set)", "source": "google", ...  1513118243
# 99999  {"referralPath": "/safeframe/1-0-14/html/conta...  1513124906
#
#        visitNumber  visitStartTime
# 0                2      1508151024
# 1                1      1508175522
# 2                1      1508143220
# 3                1      1508193530
# 4                1      1508217442
# 5                1      1508186358
# 6                1      1508203650
# 7                1      1508184397
# 8                6      1508189652
# 9                1      1508175502
# 10               1      1508190324
# 11               1      1508196731
# 12               1      1508186327
# 13               1      1508184708
# 14               1      1508186650
# 15               1      1508142222
# 16               1      1508170696
# 17               1      1508218860
# 18               1      1508187456
# 19               1      1508191999
# 20               1      1508207776
# 21               4      1508166599
# 22               1      1508153480
# 23               2      1508201784
# 24               1      1508193746
# 25               1      1508179515
# 26               2      1508185294
# 27               1      1508195772
# 28               1      1508213189
# 29               2      1508208683
# ...            ...             ...
# 99970            1      1513125912
# 99971            1      1513125898
# 99972            1      1513124944
# 99973            1      1513132402
# 99974            3      1513143094
# 99975            1      1513124915
# 99976            1      1513125210
# 99977            1      1513125109
# 99978            1      1513125627
# 99979            1      1513125076
# 99980            1      1513125415
# 99981            1      1513125378
# 99982            1      1513124983
# 99983            1      1513126925
# 99984            1      1513125082
# 99985            1      1513125122
# 99986            1      1513126662
# 99987            1      1513125201
# 99988            1      1513128278
# 99989            1      1513125037
# 99990            1      1513139781
# 99991            1      1513125068
# 99992            1      1513125051
# 99993            1      1513125101
# 99994            1      1513143644
# 99995            1      1513126207
# 99996            1      1513124975
# 99997            2      1513104037
# 99998            1      1513118243
# 99999            1      1513124906
#
# [100000 rows x 12 columns]
